# %% [markdown]
# # CSE351  Quiz 2
# # This quiz contains 2 short questions and 2 coding questions.
#
# Time Limit : 30 Minutes
#
# Total Marks : 100

# %% [markdown]
# **Instructions** :
#
# - **The quiz has two parts, Part A (MCQ) & Part B (Coding Questions)**
# - **Only one answer is correct in MCQ **
# - **You have to run the cells for the first two questions and select the correct choices from MCQ.** </br>
# - **You don't have to change any code in ipython drawer helper function**.

# %%
# Please don't change the below code.
# this is a helper function, so don't worry if you don't how it works.
# all you need to do run this cell. 
# ipython drawer helper function

import random,time
import random
import time
from IPython.display import Image, display, clear_output
from ipywidgets import widgets


def redraw():   
    """Function to draw the widgets in Jupyter notebook
    """
    choices = random.sample(x, nchoices)
    correct = random.choice(choices)
    time.sleep(3)
    buttons = [widgets.Button(description = choice) for choice in choices]

    container = widgets.HBox(children=buttons)
    display(container)

    def on_button_clicked(b):
        print("Recorded Answer: ",str(b.description))
        answer_recorded = str(b.description)
        b.color = 'blue'
        
    for button in buttons:
        button.on_click(on_button_clicked)

# %% [markdown]
# ## PART - A
# ### MCQ Questions

# %% [markdown]
# -------------

# %% [markdown]
# ## **Question 1** [5 Marks] : Can an outlier be negative? <br>
# ### if you run the below cell,  a yes and a no bottom would pop up and you just need to click on what you think is correct answer.

# %%
nchoices = 2
x = ['yes', 'no']

answer_recorded = None


print("Can there be a negative outlier? (yes or no)")
print("\nClick the button below to submit your answer")
redraw()
# Out:
# Can there be a negative outlier? (yes or no)
#
# Click the button below to submit your answer
# HBox(children=(Button(description='yes', style=ButtonStyle()), Button(description='no', style=ButtonStyle())))
# Recorded Answer:  yes
# Recorded Answer:  no
# Recorded Answer:  yes

# %% [markdown]
# ------------------

# %% [markdown]
# **Question 2** [10 Marks]
#
# There is a data which contains the runs made by a cricket player in the world cup. The cricket world cup happens in an interval of 4 years. The player has scored well with an average hit rate more than 90.
#
# You have been given a task of comparing his scores against another player in last four different matches.
#
# Which graph would you choose for comparision of runs in these four diffrent matches? You can assume that they score more than 50 runs in every game (last four matches).
#
# Hint : Think about their data types. Which chart is most suitable for comparision of these data types?
#
# A) **Bar Chart** </br>
#
# B) **Histogram** </br>
#
# C) **Pie Chart** </br>
#
# D) **Dendogram** </br>

# %%
nchoices = 4
x = ['A', 'B', 'C', 'D']

answer_recorded = None

print("Please select your answer for question 2 : (A,B,C or D)")
print("\nClick the button below to submit your answer")
redraw()
# Out:
# Please select your answer for question 2 : (A,B,C or D)
#
# Click the button below to submit your answer
# HBox(children=(Button(description='C', style=ButtonStyle()), Button(description='D', style=ButtonStyle()), But…
# Recorded Answer:  A

# %% [markdown]
# ## PART - B
# ### Coding Questions
# ------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_url = "/Users/Kishore Thamilvanan/Desktop/quiz.csv"

# %%
df = pd.read_csv(csv_url)
df
# Out:
#       wtd_std_ThermalConductivity  wtd_gmean_Valence  \
# 0                       27.027153           2.297397
# 1                        3.808916           4.257729
# 2                      138.545298           2.235267
# 3                      159.617890           1.823445
# 4                        6.258147           4.949857
# 5                       46.400000           4.337887
# 6                      137.253475           2.266014
# 7                      166.211911           2.063661
# 8                      167.295739           2.064368
# 9                      137.579265           2.259897
# 10                      17.533967           3.393458
# 11                     136.622330           2.254649
# 12                     166.260841           2.063711
# 13                      29.854855           3.231449
# 14                     170.976720           2.058579
# 15                      45.069748           2.756059
# 16                      16.462251           6.754083
# 17                     138.336896           2.232048
# 18                     127.501697           2.252954
# 19                     124.942530           2.062572
# 20                      61.598047           4.774224
# 21                      17.290971           3.469568
# 22                     135.342034           2.258061
# 23                     209.604274           1.360790
# 24                       5.588703           6.000000
# 25                     167.088722           2.080850
# 26                     167.554004           2.064676
# 27                      62.696801           2.620741
# 28                      31.464790           3.027157
# 29                     147.192100           2.193478
# ...                           ...                ...
# 8475                   137.579265           2.259897
# 8476                     0.376425           5.000000
# 8477                   123.451930           2.149488
# 8478                    23.588458           3.422478
# 8479                   138.361103           2.214646
# 8480                    25.717729           4.111016
# 8481                    29.603284           2.292286
# 8482                    14.539449           4.183121
# 8483                    35.225421           3.785552
# 8484                     4.763140           5.421612
# 8485                   127.173615           3.356819
# 8486                   138.480008           2.232679
# 8487                    34.593171           4.692074
# 8488                   165.281405           2.207140
# 8489                   166.477287           2.063362
# 8490                   158.781794           2.103868
# 8491                    59.006549           4.038808
# 8492                     4.763140           6.000000
# 8493                    23.570226           2.924018
# 8494                    27.276811           3.739269
# 8495                   190.662070           2.119268
# 8496                   146.303228           2.069808
# 8497                   159.501272           2.000000
# 8498                    45.404192           4.202007
# 8499                    24.446839           3.903699
# 8500                   166.653419           2.063611
# 8501                    31.456389           3.393458
# 8502                    30.481881           2.139306
# 8503                    20.518955           4.711734
# 8504                     2.000000           3.464102
#
#       range_ThermalConductivity  wtd_mean_atomic_mass  \
# 0                     199.97342             35.983910
# 1                       7.97342             94.391875
# 2                     399.97342             57.889752
# 3                     399.97342             45.296080
# 4                      60.00000             51.026771
# 5                     116.00000             92.171200
# 6                     399.97342             59.549919
# 7                     399.97342             53.622862
# 8                     399.97342             51.796388
# 9                     399.97342             59.224400
# 10                     44.00000             69.830640
# 11                    399.97342             58.401794
# 12                    399.97342             51.439672
# 13                     78.97342             70.631083
# 14                    399.97342             50.315865
# 15                    127.00000             40.420907
# 16                     39.00000                   NaN
# 17                    399.97342             57.069533
# 18                    399.97342             50.740282
# 19                    399.97342             33.520076
# 20                    143.00000                   NaN
# 21                     44.00000             74.286288
# 22                    399.97342             59.159589
# 23                    429.97342             51.226519
# 24                     30.00000                   NaN
# 25                    399.97342             56.244604
# 26                    399.97342             51.964977
# 27                    133.00000             15.309000
# 28                     78.97342             77.391475
# 29                    399.97342             53.861351
# ...                         ...                   ...
# 8475                  399.97342             59.224400
# 8476                    3.00000                   NaN
# 8477                  399.97342             69.280820
# 8478                   82.00000             79.863451
# 8479                  399.97342             56.149432
# 8480                  128.00000             52.320509
# 8481                   69.00000             42.601543
# 8482                   50.00000             56.123302
# 8483                   88.00000                   NaN
# 8484                   11.00000             78.991375
# 8485                  307.00000                   NaN
# 8486                  399.97342             57.175142
# 8487                   79.00000                   NaN
# 8488                  399.97342             73.107167
# 8489                  399.97342             57.865738
# 8490                  399.97342             43.600947
# 8491                  134.00000                   NaN
# 8492                   11.00000                   NaN
# 8493                   50.00000                   NaN
# 8494                   85.00000             76.162140
# 8495                  399.97342             85.539400
# 8496                  399.97342             50.907090
# 8497                  399.97342             50.482800
# 8498                  302.00000                   NaN
# 8499                   53.97417             47.538282
# 8500                  399.97342             51.381751
# 8501                   78.76400             71.509846
# 8502                   84.97342             22.874920
# 8503                  181.00000             98.210679
# 8504                    4.00000             51.017500
#
#       wtd_mean_ThermalConductivity  critical_temp
# 0                        13.890948          0.500
# 1                         3.083520          4.100
# 2                        60.929474         26.000
# 3                       109.080992         76.000
# 4                        31.660000          3.820
# 5                        46.200000          5.180
# 6                        71.194176         77.000
# 7                        98.004982         78.000
# 8                        97.904746         64.000
# 9                        72.414176         92.000
# 10                       58.600000         38.000
# 11                       71.036582         89.100
# 12                       96.433426         83.000
# 13                       40.004430         39.300
# 14                      103.467465         89.000
# 15                       65.466667         14.000
# 16                       57.048000          1.670
# 17                       61.029752         40.000
# 18                       59.827400         32.000
# 19                       72.125878         21.000
# 20                      128.925000          6.500
# 21                       58.344000         16.000
# 22                       71.062176         33.800
# 23                      167.247141          1.500
# 24                      121.080000          0.410
# 25                       98.512813         59.200
# 26                       98.365710         82.600
# 27                       71.333333         40.500
# 28                       35.006673         45.000
# 29                       89.248200         93.000
# ...                            ...            ...
# 8475                     72.414176         81.100
# 8476                     56.952000          4.470
# 8477                     53.236989         45.000
# 8478                     55.821600         22.500
# 8479                     61.626617         19.000
# 8480                     28.720000          2.400
# 8481                    114.497992          6.500
# 8482                     35.261600          4.650
# 8483                     39.991071          8.200
# 8484                    141.750000          1.402
# 8485                     80.540000          3.400
# 8486                     61.186617         26.200
# 8487                     37.250000          3.680
# 8488                    146.010636         52.000
# 8489                     96.322005         87.000
# 8490                     90.225058         21.000
# 8491                    114.736842          3.770
# 8492                    141.750000          8.350
# 8493                     24.666667          4.250
# 8494                     64.340000         20.100
# 8495                    180.089511         90.700
# 8496                     88.645082         68.550
# 8497                    112.228290        126.000
# 8498                     67.441176          5.190
# 8499                     23.935196          1.860
# 8500                     96.771022         93.500
# 8501                     45.844368         20.800
# 8502                     19.883760          8.300
# 8503                     59.350000         18.000
# 8504                     25.000000          2.800
#
# [8505 rows x 6 columns]

# %% [markdown]
# Q3 [15 Marks].
#
# Part 3.1) Does this dataframe contain any missing values? </br>
#
# Part 3.2) Can you find which column has missing values if there exists such column? </br>
#
# Part 3.3) If yes, Drop all rows which has missing values? </br>
#
# Hint : You can use pandas in-built functions

# %% [markdown]
# 1. yes this df has a lot of missing values.

# %%
df.isnull()
# Out:
#       wtd_std_ThermalConductivity  wtd_gmean_Valence  \
# 0                           False              False
# 1                           False              False
# 2                           False              False
# 3                           False              False
# 4                           False              False
# 5                           False              False
# 6                           False              False
# 7                           False              False
# 8                           False              False
# 9                           False              False
# 10                          False              False
# 11                          False              False
# 12                          False              False
# 13                          False              False
# 14                          False              False
# 15                          False              False
# 16                          False              False
# 17                          False              False
# 18                          False              False
# 19                          False              False
# 20                          False              False
# 21                          False              False
# 22                          False              False
# 23                          False              False
# 24                          False              False
# 25                          False              False
# 26                          False              False
# 27                          False              False
# 28                          False              False
# 29                          False              False
# ...                           ...                ...
# 8475                        False              False
# 8476                        False              False
# 8477                        False              False
# 8478                        False              False
# 8479                        False              False
# 8480                        False              False
# 8481                        False              False
# 8482                        False              False
# 8483                        False              False
# 8484                        False              False
# 8485                        False              False
# 8486                        False              False
# 8487                        False              False
# 8488                        False              False
# 8489                        False              False
# 8490                        False              False
# 8491                        False              False
# 8492                        False              False
# 8493                        False              False
# 8494                        False              False
# 8495                        False              False
# 8496                        False              False
# 8497                        False              False
# 8498                        False              False
# 8499                        False              False
# 8500                        False              False
# 8501                        False              False
# 8502                        False              False
# 8503                        False              False
# 8504                        False              False
#
#       range_ThermalConductivity  wtd_mean_atomic_mass  \
# 0                         False                 False
# 1                         False                 False
# 2                         False                 False
# 3                         False                 False
# 4                         False                 False
# 5                         False                 False
# 6                         False                 False
# 7                         False                 False
# 8                         False                 False
# 9                         False                 False
# 10                        False                 False
# 11                        False                 False
# 12                        False                 False
# 13                        False                 False
# 14                        False                 False
# 15                        False                 False
# 16                        False                  True
# 17                        False                 False
# 18                        False                 False
# 19                        False                 False
# 20                        False                  True
# 21                        False                 False
# 22                        False                 False
# 23                        False                 False
# 24                        False                  True
# 25                        False                 False
# 26                        False                 False
# 27                        False                 False
# 28                        False                 False
# 29                        False                 False
# ...                         ...                   ...
# 8475                      False                 False
# 8476                      False                  True
# 8477                      False                 False
# 8478                      False                 False
# 8479                      False                 False
# 8480                      False                 False
# 8481                      False                 False
# 8482                      False                 False
# 8483                      False                  True
# 8484                      False                 False
# 8485                      False                  True
# 8486                      False                 False
# 8487                      False                  True
# 8488                      False                 False
# 8489                      False                 False
# 8490                      False                 False
# 8491                      False                  True
# 8492                      False                  True
# 8493                      False                  True
# 8494                      False                 False
# 8495                      False                 False
# 8496                      False                 False
# 8497                      False                 False
# 8498                      False                  True
# 8499                      False                 False
# 8500                      False                 False
# 8501                      False                 False
# 8502                      False                 False
# 8503                      False                 False
# 8504                      False                 False
#
#       wtd_mean_ThermalConductivity  critical_temp
# 0                            False          False
# 1                            False          False
# 2                            False          False
# 3                            False          False
# 4                            False          False
# 5                            False          False
# 6                            False          False
# 7                            False          False
# 8                            False          False
# 9                            False          False
# 10                           False          False
# 11                           False          False
# 12                           False          False
# 13                           False          False
# 14                           False          False
# 15                           False          False
# 16                           False          False
# 17                           False          False
# 18                           False          False
# 19                           False          False
# 20                           False          False
# 21                           False          False
# 22                           False          False
# 23                           False          False
# 24                           False          False
# 25                           False          False
# 26                           False          False
# 27                           False          False
# 28                           False          False
# 29                           False          False
# ...                            ...            ...
# 8475                         False          False
# 8476                         False          False
# 8477                         False          False
# 8478                         False          False
# 8479                         False          False
# 8480                         False          False
# 8481                         False          False
# 8482                         False          False
# 8483                         False          False
# 8484                         False          False
# 8485                         False          False
# 8486                         False          False
# 8487                         False          False
# 8488                         False          False
# 8489                         False          False
# 8490                         False          False
# 8491                         False          False
# 8492                         False          False
# 8493                         False          False
# 8494                         False          False
# 8495                         False          False
# 8496                         False          False
# 8497                         False          False
# 8498                         False          False
# 8499                         False          False
# 8500                         False          False
# 8501                         False          False
# 8502                         False          False
# 8503                         False          False
# 8504                         False          False
#
# [8505 rows x 6 columns]

# %% [markdown]
# 2. YES,

# %% [markdown]
# 3.

# %%
df.isnull().sum()
# Out:
# wtd_std_ThermalConductivity        0
# wtd_gmean_Valence                  0
# range_ThermalConductivity          0
# wtd_mean_atomic_mass            1322
# wtd_mean_ThermalConductivity       0
# critical_temp                      0
# dtype: int64

# %%
#4.1

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

IQR = Q3 - Q1
print(IQR["wtd_std_ThermalConductivity"])
# Out:
# 130.18370561444678

# %%
#4.2

df.hist("wtd_gmean_Valence")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F7ECEC9C88>]],
#       dtype=object)

# %% [markdown]
# ----------

# %% [markdown]
# Q4 [20 Marks].
#
# Part 4.1) Count the number of elements in IQR for column 'wtd_std_ThermalConductivity'

# %% [markdown]
# Part 4.2) Plot histogram for column 'wtd_gmean_Valence'

# %% [markdown]
# Part 4.3.1) Plot scatter plot between input variable 'wtd_mean_atomic_mass' and target variable 'critical_temp'
#
# Part 4.3.2) Does this plot contain outliers? (Yes|No)

# %% [markdown]
#  -------------------------
# |** ---- FINISHED ---- ** |
#  -------------------------
